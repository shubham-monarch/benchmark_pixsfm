# %%
# %load_ext autoreload
# %autoreload 2
import tqdm, tqdm.notebook
tqdm.tqdm = tqdm.notebook.tqdm  # notebook-friendly progress bars
import os
import time
import sys
from hloc import extract_features, match_features, reconstruction, pairs_from_exhaustive, visualization
from hloc.visualization import plot_images, read_image
from hloc.utils.viz_3d import init_figure, plot_points, plot_reconstruction, plot_camera_colmap
from pixsfm.util.visualize import init_image, plot_points2D
from pixsfm.refine_hloc import PixSfM
from pixsfm import ostream_redirect
from PIL import Image, ImageDraw
import pycolmap
from pathlib import Path
#import visualize_model
# redirect the C++ outputs to notebook cells
cpp_out = ostream_redirect(stderr=True, stdout=True)
cpp_out.__enter__()

# %%
sys.path.insert(0, "./scripts/")
import svo_to_pointcloud

# %%
svo_file_path = "/home/skumar/front_svo/front_2023-11-03-10-51-17.svo"
nb_frames = 40

# %%
svo_to_pointcloud.main(svo_file_path, nb_frames)
# Out:
# Desired number of frames: 40
# Reading SVO file: /home/skumar/front_svo/front_2023-11-03-10-51-17.svo
# clear old output
# num_frames in svo: 1198
# Doing 0
# Writing images
# Writing point cloud of resolution
# Translation: Tx: 0.0, Ty: 0.0, Tz 0.0, Timestamp: 1699033887930
#
# Orientation: Ox: -0.245, Oy: 0.001, Oz 0.005, Ow: 0.97
#
# Doing 1
# Writing images
# Writing point cloud of resolution
# Translation: Tx: 4.12, Ty: 1.833, Tz -2.655, Timestamp: 1699033888030
#
# Orientation: Ox: -0.243, Oy: -0.001, Oz 0.005, Ow: 0.97
#
# Doing 2
# Writing images
# Writing point cloud of resolution
# Translation: Tx: 4.053, Ty: 1.667, Tz -2.497, Timestamp: 1699033888097
#
# Orientation: Ox: -0.244, Oy: -0.0, Oz 0.005, Ow: 0.97
#
# Doing 3
# Writing images
# Writing point cloud of resolution
# Translation: Tx: 3.865, Ty: 2.258, Tz -2.462, Timestamp: 1699033888164
#
# Orientation: Ox: -0.243, Oy: -0.001, Oz 0.004, Ow: 0.97
#
# Doing 4
# Writing images
# Writing point cloud of resolution
# Translation: Tx: -0.436, Ty: 4.515, Tz -2.613, Timestamp: 1699033888264
#
# Orientation: Ox: -0.242, Oy: -0.002, Oz -0.0, Ow: 0.97
#
# Doing 5
# Writing images
# Writing point cloud of resolution
# Translation: Tx: -5.431, Ty: 6.804, Tz -1.947, Timestamp: 1699033888364
#
# Orientation: Ox: -0.241, Oy: -0.004, Oz -0.005, Ow: 0.97
#
# Doing 6
# Writing images
# Writing point cloud of resolution
# Translation: Tx: -8.391, Ty: 9.485, Tz -1.701, Timestamp: 1699033888465
#
# Orientation: Ox: -0.24, Oy: -0.006, Oz -0.009, Ow: 0.971
#
# Doing 7
# Writing images
# Writing point cloud of resolution
# Translation: Tx: -8.131, Ty: 11.165, Tz -0.457, Timestamp: 1699033888565
#
# Orientation: Ox: -0.239, Oy: -0.009, Oz -0.01, Ow: 0.971
#
# Doing 8
# Writing images
# Writing point cloud of resolution
# Translation: Tx: -4.927, Ty: 13.106, Tz 0.661, Timestamp: 1699033888665
#
# Orientation: Ox: -0.239, Oy: -0.011, Oz -0.011, Ow: 0.971
#
# Doing 9
# Writing images
# Writing point cloud of resolution
# Translation: Tx:
# Writing images
# Writing point cloud of resolution
# Translation: Tx: -29.815, Ty: 52.651, Tz 4.596, Timestamp: 1699033890371
#
# Orientation: Ox: -0.223, Oy: -0.025, Oz -0.041, Ow: 0.974
#
# Doing 26
# Writing images
# Writing point cloud of resolution
# Translation: Tx: -31.227, Ty: 54.057, Tz 5.138, Timestamp: 1699033890472
#
# Orientation: Ox: -0.222, Oy: -0.023, Oz -0.04, Ow: 0.974
#
# Doing 27
# Writing images
# Writing point cloud of resolution
# Translation: Tx: -36.685, Ty: 56.613, Tz 4.882, Timestamp: 1699033890572
#
# Orientation: Ox: -0.221, Oy: -0.021, Oz -0.041, Ow: 0.974
#
# Doing 28
# Writing images
# Writing point cloud of resolution
# Translation: Tx: -43.447, Ty: 59.497, Tz 5.522, Timestamp: 1699033890672
#
# Orientation: Ox: -0.221, Oy: -0.02, Oz -0.043, Ow: 0.974
#
# Doing 29
# Writing images
# Writing point cloud of resolution
# Translation: Tx: -47.786, Ty: 62.423, Tz 5.561, Timestamp: 1699033890739
#
# Orientation: Ox: -0.22, Oy: -0.019, Oz -0.046, Ow: 0.974
#
# Doing 30
# Writing images
# Writing point cloud of resolution
# Translation: Tx: -51.039, Ty: 66.704, Tz 4.21, Timestamp: 1699033890840
#
# Orientation: Ox: -0.217, Oy: -0.019, Oz -0.048, Ow: 0.975
#
# Doing 31
# Writing images
# Writing point cloud of resolution
# Translation: Tx: -57.594, Ty: 68.789, Tz 3.553, Timestamp: 1699033890940
#
# Orientation: Ox: -0.217, Oy: -0.018, Oz -0.05, Ow: 0.975
#
# Doing 32
# Writing images
# Writing point cloud of resolution
# Translation: Tx: -57.891, Ty: 70.867, Tz 2.729, Timestamp: 1699033891040
#
# Orientation: Ox: -0.216, Oy: -0.019, Oz -0.051, Ow: 0.975
#
# Doing 33
# Writing images
# Writing point cloud of resolution
# Translation: Tx: -58.706, Ty: 73.826, Tz 0.685, Timestamp: 1699033891141
#
# Orientation: Ox: -0.214, Oy: -0.019, Oz -0.052, Ow: 0.975
#
# Doing 34
# Writing images
# Writing point cloud of resolution
# Translation: Tx: -60.237, Ty: 75.501, Tz 0.425, Timestamp: 1699033891208
#
# Orientation: Ox: -0.214, Oy: -0.019, Oz -0.053, Ow: 0.975
#
# Doing 35
# Writing images
# Writing point cloud of resolution
# Translation: Tx: -64.31, Ty: 77.029, Tz 0.624, Timestamp: 1699033891342
#
# Orientation: Ox: -0.214, Oy: -0.018, Oz -0.055, Ow: 0.975
#
# Doing 36
# Writing images
# Writing point cloud of resolution
# Translation: Tx: -72.425, Ty: 80.62, Tz -1.32, Timestamp: 1699033891442
#
# Orientation: Ox: -0.212, Oy: -0.017, Oz -0.058, Ow: 0.975
#
# Doing 37
# Writing images
# Writing point cloud of resolution
# Translation: Tx: -75.809, Ty: 82.427, Tz -0.642, Timestamp: 1699033891542
#
# Orientation: Ox: -0.212, Oy: -0.017, Oz -0.061, Ow: 0.975
#
# Doing 38
# Writing images
# Writing point cloud of resolution
# Translation: Tx: -77.834, Ty: 85.07, Tz -0.685, Timestamp: 1699033891643
#
# Orientation: Ox: -0.211, Oy: -0.018, Oz -0.063, Ow: 0.975
#
# Doing 39
# Writing images
# Writing point cloud of resolution
# Translation: Tx: -78.917, Ty: 86.659, Tz -1.103, Timestamp: 1699033891743
#
# Orientation: Ox: -0.21, Oy: -0.017, Oz -0.062, Ow: 0.976
#
#
# SVO end has been reached. Exiting now.

# %%
print("svo pipeline finished")
# Out:
# svo pipeline finished
